# %% [markdown]
# # 🏰 迪士尼乐园路径规划可视化系统
#
# ## 纯 Python 标准库实现，无需安装任何第三方包
#
# ### 使用说明
#
# 1. 运行下面两个代码单元格
# 2. 等待数据加载完成（约10-30秒）
# 3. 浏览器会自动打开 **http://127.0.0.1:5000**
# 4. 在网页界面中输入参数，点击"开始路径规划"
# 5. 查看结果：Top5满意度排名 + 三项目路线规划
#
# > ⚠️ 运行期间请勿关闭此Notebook，关闭即停止服务

# %%
# Cell 1: 切换到工作目录
import os
import webbrowser
import threading
import time

os.chdir(r"D:\桌面\可视化界面尝试")

print("=" * 60)
print("  准备启动迪士尼路径规划可视化系统...")
print("  数据加载中，请稍候...")
print("=" * 60)

# 延迟打开浏览器
def open_browser():
    time.sleep(3)
    webbrowser.open("http://127.0.0.1:5000")

threading.Thread(target=open_browser, daemon=True).start()

# %%
# Cell 2: 运行主程序 (这个Cell会持续运行直到你手动停止)
# 停止方法：点击 Jupyter 的 ■ 停止按钮，或在 Spyder 中按 Ctrl+C
# %run app.py

# %% [markdown]
# ---
# ### 备选启动方式
#
# **Spyder 中运行：**
# 打开 `app.py` → 按 F5 运行
#
# **命令行运行：**
# ```bash
# cd "D:\桌面\可视化界面尝试"
# python app.py
# ```
#
# 然后在浏览器中访问 `http://127.0.0.1:5000`
#
# ---
# ### 依赖项
#
# 本系统使用 **纯 Python 标准库** + pandas + numpy + openpyxl
# （均为 Jupyter/Spyder 默认环境自带，无需额外安装）
